# %% [markdown]
# # README
#
# Upload the data to the open search through langchain.
#
# **References**
# * [OpenSearch Langchain](https://python.langchain.com/v0.2/docs/integrations/vectorstores/opensearch/)

# %% [markdown]
# # Install & Import

# %%
# %pip install --upgrade --quiet  opensearch-py langchain-community python-dotenv langchain_openai
# %pip install --upgrade --quiet transformers sentence-transformers pandas
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 8228.47s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Note: you may need to restart the kernel to use updated packages.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# 8234.93s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# `similarity_search` by default performs the Approximate `k-NN` Search which uses one of the several algorithms like `lucene`, `nmslib`, `faiss` recommended for large datasets. To perform brute force search we have other search methods known as `Script Scoring` and `Painless Scripting`. Check this for more details.

# %%
import os
import textwrap
from dotenv import load_dotenv
from langchain_community.document_loaders import TextLoader
from langchain_community.vectorstores import OpenSearchVectorSearch
from langchain_openai import OpenAIEmbeddings
from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from langchain_text_splitters import CharacterTextSplitter

load_dotenv()
# Out:
# True

# %%
import getpass
import os

# os.environ["OPENAI_API_KEY"] = getpass.getpass("OpenAI API Key:")

# %% [markdown]
# **state_of_the_union.txt**
#
# For this text file you can download from these link [state_of_the_union.txt](https://github.com/hwchase17/chroma-langchain/blob/master/state_of_the_union.txt)
#
#
#
# In LangChain, the state_of_the_union.txt file is often used as a sample text document for demonstrating various functionalities like text processing, document loading, and embedding. The file typically contains the transcript of a U.S. president's State of the Union address, which is a speech given annually to outline the current condition of the country and the administration's legislative agenda.

# %% [markdown]
# **Embeddings**
#
# We can use the Huggingface Embeddings for free instead of the OpenAI Embeddings
#
# * [sentence-transformers/all-MiniLM-L6-v2](https://huggingface.co/sentence-transformers/all-MiniLM-L6-v2)

# %% [markdown]
# # Start

# %%
loader = TextLoader("./state_of_the_union.txt")
loader

# %%
documents = loader.load()
documents
# Out:
# [Document(metadata={'source': './state_of_the_union.txt'}, page_content='Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.  \n\nLast year COVID-19 kept us apart. This year we are finally together again. \n\nTonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. \n\nWith a duty to one another to the American people to the Constitution. \n\nAnd with an unwavering resolve that freedom will always triumph over tyranny. \n\nSix days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. \n\nHe thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. \n\nHe met the Ukrainian people. \n\nFrom President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world. \n\nGroups of citizens blocking tanks with their bodies. Everyone from students to retirees teachers turned soldiers defending their homeland. \n\nIn this struggle as President Zelenskyy said in his speech to the European Parliament “Light will win over darkness.” The Ukrainian Ambassador to the United States is here tonight. \n\nLet each of us here tonight in this Chamber send an unmistakable signal to Ukraine and to the world. \n\nPlease rise if you are able and show that, Yes, we the United States of America stand with the Ukrainian people. \n\nThroughout our history we’ve learned this lesson when dictators do not pay a price for their aggression they cause more chaos.   \n\nThey keep moving.   \n\nAnd the costs and the threats to America and the world keep rising.   \n\nThat’s why the NATO Alliance was created to secure peace and stability in Europe after World War 2. \n\nThe United States is a member along with 29 other nations. \n\nIt matters. American diplomacy matters. American resolve matters. \n\nPutin’s latest attack on Ukraine was premeditated and unprovoked. \n\nHe rejected repeated efforts at diplomacy. \n\nHe thought the West and NATO wouldn’t respond. And he thought he could divide us at home. Putin was wrong. We were ready.  Here is what we did.   \n\nWe prepared extensively and carefully. \n\nWe spent months building a coalition of other freedom-loving nations from Europe and the Americas to Asia and Africa to confront Putin. \n\nI spent countless hours unifying our European allies. We shared with the world in advance what we knew Putin was planning and precisely how he would try to falsely justify his aggression.  \n\nWe countered Russia’s lies with truth.   \n\nAnd now that he has acted the free world is holding him accountable. \n\nAlong with twenty-seven members of the European Union including France, Germany, Italy, as well as countries like the United Kingdom, Canada, Japan, Korea, Australia, New Zealand, and many others, even Switzerland. \n\nWe are inflicting pain on Russia and supporting the people of Ukraine. Putin is now isolated from the world more than ever. \n\nTogether with our allies –we are right now enforcing powerful economic sanctions. \n\nWe are cutting off Russia’s largest banks from the international financial system.  \n\nPreventing Russia’s central bank from defending the Russian Ruble making Putin’s $630 Billion “war fund” worthless.   \n\nWe are choking off Russia’s access to technology that will sap its economic strength and weaken its military for years to come.  \n\nTonight I say to the Russian oligarchs and corrupt leaders who have bilked billions of dollars off this violent regime no more. \n\nThe U.S. Department of Justice is assembling a dedicated task force to go after the crimes of Russian oligarchs.  \n\nWe are joining with our European allies to find and seize your yachts your luxury apartments your private jets. We are coming for your ill-begotten gains. \n\nAnd ...

# %%
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
text_splitter

# %%
docs = text_splitter.split_documents(documents)
docs[0]
# Out:
# Document(metadata={'source': './state_of_the_union.txt'}, page_content='Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.  \n\nLast year COVID-19 kept us apart. This year we are finally together again. \n\nTonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. \n\nWith a duty to one another to the American people to the Constitution. \n\nAnd with an unwavering resolve that freedom will always triumph over tyranny. \n\nSix days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. \n\nHe thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. \n\nHe met the Ukrainian people. \n\nFrom President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world.')

# %%
# embeddings = OpenAIEmbeddings()
# embeddings

embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# %% [markdown]
# # [similarity_search using Approximate k-NN](https://python.langchain.com/v0.2/docs/integrations/vectorstores/opensearch/#similarity_search-using-approximate-k-nn)

# %%
OPENSEARCH_USERNAME = os.environ.get('OPENSEARCH_USERNAME')
OPENSEARCH_PASSWORD = os.environ.get('OPENSEARCH_PASSWORD')

# %%
docsearch = OpenSearchVectorSearch.from_documents(
    docs,
    embeddings,
    opensearch_url="https://localhost:9200",
    http_auth=(OPENSEARCH_USERNAME, OPENSEARCH_PASSWORD),
    use_ssl = False,
    verify_certs = False,
    ssl_assert_hostname = False,
    ssl_show_warn = False,
    
)

# %%
query = "What did the president say about Ketanji Brown Jackson"
docs = docsearch.similarity_search(query, k=10)
docs
# Out:
# [Document(metadata={'source': './state_of_the_union.txt'}, page_content='Tonight. I call on the Senate to: Pass the Freedom to Vote Act. Pass the John Lewis Voting Rights Act. And while you’re at it, pass the Disclose Act so Americans can know who is funding our elections. \n\nTonight, I’d like to honor someone who has dedicated his life to serve this country: Justice Stephen Breyer—an Army veteran, Constitutional scholar, and retiring Justice of the United States Supreme Court. Justice Breyer, thank you for your service. \n\nOne of the most serious constitutional responsibilities a President has is nominating someone to serve on the United States Supreme Court. \n\nAnd I did that 4 days ago, when I nominated Circuit Court of Appeals Judge Ketanji Brown Jackson. One of our nation’s top legal minds, who will continue Justice Breyer’s legacy of excellence.'),
#  Document(metadata={'source': './state_of_the_union.txt'}, page_content='Madam Speaker, Madam Vice President, our First Lady and Second Gentleman. Members of Congress and the Cabinet. Justices of the Supreme Court. My fellow Americans.  \n\nLast year COVID-19 kept us apart. This year we are finally together again. \n\nTonight, we meet as Democrats Republicans and Independents. But most importantly as Americans. \n\nWith a duty to one another to the American people to the Constitution. \n\nAnd with an unwavering resolve that freedom will always triumph over tyranny. \n\nSix days ago, Russia’s Vladimir Putin sought to shake the foundations of the free world thinking he could make it bend to his menacing ways. But he badly miscalculated. \n\nHe thought he could roll into Ukraine and the world would roll over. Instead he met a wall of strength he never imagined. \n\nHe met the Ukrainian people. \n\nFrom President Zelenskyy to every Ukrainian, their fearlessness, their courage, their determination, inspires the world.'),
#  Document(metadata={'source': './state_of_the_union.txt'}, page_content='A former top litigator in private practice. A former federal public defender. And from a family of public school educators and police officers. A consensus builder. Since she’s been nominated, she’s received a broad range of support—from the Fraternal Order of Police to former judges appointed by Democrats and Republicans. \n\nAnd if we are to advance liberty and justice, we need to secure the Border and fix the immigration system. \n\nWe can do both. At our border, we’ve installed new technology like cutting-edge scanners to better detect drug smuggling.  \n\nWe’ve set up joint patrols with Mexico and Guatemala to catch more human traffickers.  \n\nWe’re putting in place dedicated immigration judges so families fleeing persecution and violence can have their cases heard faster. \n\nWe’re securing commitments and supporting partners in South and Central America to host more refugees and secure their own borders.'),
#  Document(metadata={'source': './state_of_the_union.txt'}, page_content='We can do all this while keeping lit the torch of liberty that has led generations of immigrants to this land—my forefathers and so many of yours. \n\nProvide a pathway to citizenship for Dreamers, those on temporary status, farm workers, and essential workers. \n\nRevise our laws so businesses have the workers they need and families don’t wait decades to reunite. \n\nIt’s not only the right thing to do—it’s the economically smart thing to do. \n\nThat’s why immigration reform is supported by everyone from labor unions to religious leaders to the U.S. Chamber of Commerce. \n\nLet’s get it done once and for all. \n\nAdvancing liberty and justice also requires protecting the rights of women. \n\nThe constitutional right affirmed in Roe v. Wade—standing precedent for half a century—is under attack as never before. \n\nIf we want to go forward—not backward—we must protect access to health care. Preserve a woman’s right to choose. And let’s continue to advance maternal health care in America.'),
#  Document(metadata={'source': './state_of_the_union.txt'}, page_content='As Ohio Senator Sherrod Brown says, “It’s time to bury the label “Rust Belt.” \n\nIt’s time. \n\nBut with all the bright spots in our economy, record job growth and higher wages, too many families are struggling to keep up with the bills.  \n\nInflation is robbing them of the gains they might otherwise feel. \n\nI get it. That’s why my top priority is getting prices under control. \n\nLook, our economy roared back faster than most predicted, but the pandemic meant that businesses had a hard time hiring enough workers to keep up production in their factories. \n\nThe pandemic also disrupted global supply chains. \n\nWhen factories close, it takes longer to make goods and get them from the warehouse to the store, and prices go up. \n\nLook at cars. \n\nLast year, there weren’t enough semiconductors to make all the cars that people wanted to buy. \n\nAnd guess what, prices of automobiles went up. \n\nSo—we have a choice. \n\nOne way to fight inflation is to drive down wages and make Americans poorer.'),
#  Document(metadata={'source': './state_of_the_union.txt'}, page_content='Last month, I announced our plan to supercharge  \nthe Cancer Moonshot that President Obama asked me to lead six years ago. \n\nOur goal is to cut the cancer death rate by at least 50% over the next 25 years, turn more cancers from death sentences into treatable diseases.  \n\nMore support for patients and families. \n\nTo get there, I call on Congress to fund ARPA-H, the Advanced Research Projects Agency for Health. \n\nIt’s based on DARPA—the Defense Department project that led to the Internet, GPS, and so much more.  \n\nARPA-H will have a singular purpose—to drive breakthroughs in cancer, Alzheimer’s, diabetes, and more. \n\nA unity agenda for the nation. \n\nWe can do this. \n\nMy fellow Americans—tonight , we have gathered in a sacred space—the citadel of our democracy. \n\nIn this Capitol, generation after generation, Americans have debated great questions amid great strife, and have done great things. \n\nWe have fought for freedom, expanded liberty, defeated totalitarianism and terror.'),
#  Document(metadata={'source': './state_of_the_union.txt'}, page_content='Second – we must prepare for new variants. Over the past year, we’ve gotten much better at detecting new variants. \n\nIf necessary, we’ll be able to deploy new vaccines within 100 days instead of many more months or years.  \n\nAnd, if Congress provides the funds we need, we’ll have new stockpiles of tests, masks, and pills ready if needed. \n\nI cannot promise a new variant won’t come. But I can promise you we’ll do everything within our power to be ready if it does.  \n\nThird – we can end the shutdown of schools and businesses. We have the tools we need. \n\nIt’s time for Americans to get back to work and fill our great downtowns again.  People working from home can feel safe to begin to return to the office.   \n\nWe’re doing that here in the federal government. The vast majority of federal workers will once again work in person. \n\nOur schools are open. Let’s keep it that way. Our kids need to be in school.'),
#  Document(metadata={'source': './state_of_the_union.txt'}, page_content='And for our LGBTQ+ Americans, let’s finally get the bipartisan Equality Act to my desk. The onslaught of state laws targeting transgender Americans and their families is wrong. \n\nAs I said last year, especially to our younger transgender Americans, I will always have your back as your President, so you can be yourself and reach your God-given potential. \n\nWhile it often appears that we never agree, that isn’t true. I signed 80 bipartisan bills into law last year. From preventing government shutdowns to protecting Asian-Americans from still-too-common hate crimes to reforming military justice. \n\nAnd soon, we’ll strengthen the Violence Against Women Act that I first wrote three decades ago. It is important for us to show the nation that we can come together and do big things. \n\nSo tonight I’m offering a Unity Agenda for the Nation. Four big things we can do together.  \n\nFirst, beat the opioid epidemic.'),
#  Document(metadata={'source': './state_of_the_union.txt'}, page_content='As Frances Haugen, who is here with us tonight, has shown, we must hold social media platforms accountable for the national experiment they’re conducting on our children for profit. \n\nIt’s time to strengthen privacy protections, ban targeted advertising to children, demand tech companies stop collecting personal data on our children. \n\nAnd let’s get all Americans the mental health services they need. More people they can turn to for help, and full parity between physical and mental health care. \n\nThird, support our veterans. \n\nVeterans are the best of us. \n\nI’ve always believed that we have a sacred obligation to equip all those we send to war and care for them and their families when they come home. \n\nMy administration is providing assistance with job training and housing, and now helping lower-income veterans get VA care debt-free.  \n\nOur troops in Iraq and Afghanistan faced many dangers.'),
#  Document(metadata={'source': './state_of_the_union.txt'}, page_content='And my report is this: the State of the Union is strong—because you, the American people, are strong. \n\nWe are stronger today than we were a year ago. \n\nAnd we will be stronger a year from now than we are today. \n\nNow is our moment to meet and overcome the challenges of our time. \n\nAnd we will, as one people. \n\nOne America. \n\nThe United States of America. \n\nMay God bless you all. May God protect our troops.')]

# %%
print(docs[0].page_content)
# Out:
# Tonight. I call on the Senate to: Pass the Freedom to Vote Act. Pass the John Lewis Voting Rights Act. And while you’re at it, pass the Disclose Act so Americans can know who is funding our elections.
#
# Tonight, I’d like to honor someone who has dedicated his life to serve this country: Justice Stephen Breyer—an Army veteran, Constitutional scholar, and retiring Justice of the United States Supreme Court. Justice Breyer, thank you for your service.
#
# One of the most serious constitutional responsibilities a President has is nominating someone to serve on the United States Supreme Court.
#
# And I did that 4 days ago, when I nominated Circuit Court of Appeals Judge Ketanji Brown Jackson. One of our nation’s top legal minds, who will continue Justice Breyer’s legacy of excellence.

# %%
docsearch = OpenSearchVectorSearch.from_documents(
    docs,
    embeddings,
    opensearch_url="https://localhost:9200",
    http_auth=(OPENSEARCH_USERNAME, OPENSEARCH_PASSWORD),
    use_ssl = False,
    verify_certs = False,
    ssl_assert_hostname = False,
    ssl_show_warn = False,
    engine="faiss",
    space_type="innerproduct",
    ef_construction=256,
    m=48,
    
)

# %%
query = "What did the president say about Ketanji Brown Jackson"
docs = docsearch.similarity_search(query)

# %%
print(docs[0].page_content)
# Out:
# Tonight. I call on the Senate to: Pass the Freedom to Vote Act. Pass the John Lewis Voting Rights Act. And while you’re at it, pass the Disclose Act so Americans can know who is funding our elections.
#
# Tonight, I’d like to honor someone who has dedicated his life to serve this country: Justice Stephen Breyer—an Army veteran, Constitutional scholar, and retiring Justice of the United States Supreme Court. Justice Breyer, thank you for your service.
#
# One of the most serious constitutional responsibilities a President has is nominating someone to serve on the United States Supreme Court.
#
# And I did that 4 days ago, when I nominated Circuit Court of Appeals Judge Ketanji Brown Jackson. One of our nation’s top legal minds, who will continue Justice Breyer’s legacy of excellence.

# %% [markdown]
# # [similarity_search using Script Scoring](https://python.langchain.com/v0.2/docs/integrations/vectorstores/opensearch/#similarity_search-using-script-scoring)
#
# `similarity_search` using `Script Scoring` with Custom Parameters

# %%
docsearch = OpenSearchVectorSearch.from_documents(
    docs,
    embeddings,
    opensearch_url="https://localhost:9200",
    http_auth=(OPENSEARCH_USERNAME, OPENSEARCH_PASSWORD),
    use_ssl = False,
    verify_certs = False,
    ssl_assert_hostname = False,
    ssl_show_warn = False,
    is_appx_search=False
)

query = "What did the president say about Ketanji Brown Jackson"
docs = docsearch.similarity_search(
    "What did the president say about Ketanji Brown Jackson",
    k=1,
    search_type="script_scoring",
)

# %%
print((docs[0].page_content))
# Out:
# Tonight. I call on the Senate to: Pass the Freedom to Vote Act. Pass the John Lewis Voting Rights Act. And while you’re at it, pass the Disclose Act so Americans can know who is funding our elections.
#
# Tonight, I’d like to honor someone who has dedicated his life to serve this country: Justice Stephen Breyer—an Army veteran, Constitutional scholar, and retiring Justice of the United States Supreme Court. Justice Breyer, thank you for your service.
#
# One of the most serious constitutional responsibilities a President has is nominating someone to serve on the United States Supreme Court.
#
# And I did that 4 days ago, when I nominated Circuit Court of Appeals Judge Ketanji Brown Jackson. One of our nation’s top legal minds, who will continue Justice Breyer’s legacy of excellence.

# %% [markdown]
# # [similarity_search using Painless Scripting](https://python.langchain.com/v0.2/docs/integrations/vectorstores/opensearch/#similarity_search-using-painless-scripting)

# %%
docsearch = OpenSearchVectorSearch.from_documents(
    docs,
    embeddings,
    opensearch_url="https://localhost:9200",
    http_auth=(OPENSEARCH_USERNAME, OPENSEARCH_PASSWORD),
    use_ssl = False,
    verify_certs = False,
    ssl_assert_hostname = False,
    ssl_show_warn = False,
    is_appx_search=False
)

# %%
filter = {"bool": {"filter": {"term": {"text": "smuggling"}}}}
query = "What did the president say about Ketanji Brown Jackson"
docs = docsearch.similarity_search(
    "What did the president say about Ketanji Brown Jackson",
    search_type="painless_scripting",
    space_type="cosineSimilarity",
    pre_filter=filter,
)

# %%
print(docs[0].page_content)
# Out:
# A former top litigator in private practice. A former federal public defender. And from a family of public school educators and police officers. A consensus builder. Since she’s been nominated, she’s received a broad range of support—from the Fraternal Order of Police to former judges appointed by Democrats and Republicans.
#
# And if we are to advance liberty and justice, we need to secure the Border and fix the immigration system.
#
# We can do both. At our border, we’ve installed new technology like cutting-edge scanners to better detect drug smuggling.
#
# We’ve set up joint patrols with Mexico and Guatemala to catch more human traffickers.
#
# We’re putting in place dedicated immigration judges so families fleeing persecution and violence can have their cases heard faster.
#
# We’re securing commitments and supporting partners in South and Central America to host more refugees and secure their own borders.

# %% [markdown]
# # [Maximum marginal relevance search (MMR)](https://python.langchain.com/v0.2/docs/integrations/vectorstores/opensearch/#maximum-marginal-relevance-search-mmr)
#
# If you’d like to look up for some similar documents, but you’d also like to receive `diverse results`, MMR is method you should consider. Maximal marginal relevance optimizes for similarity to query AND diversity among selected documents.

# %%
query = "What did the president say about Ketanji Brown Jackson"
docs = docsearch.max_marginal_relevance_search(query, k=2, fetch_k=10, lambda_param=0.5)

# %%
print(docs[0].page_content)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 print(docs[0].page_content)
#
# IndexError: list index out of range

# %%
docsearch = OpenSearchVectorSearch(
    index_name="index-*",
    embedding_function=embeddings,
    opensearch_url="http://localhost:9200",
    use_ssl = False,
    verify_certs = False,
    ssl_assert_hostname = False,
    ssl_show_warn = False,
    is_appx_search=False
)

# %%
# you can specify custom field names to match the fields you're using to store your embedding, document text value, and metadata
docs = docsearch.similarity_search(
    "Who was asking about getting lunch today?",
    search_type="script_scoring",
    space_type="cosinesimil",
    vector_field="message_embedding",
    text_field="message",
    metadata_field="message_metadata",
)
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/_practice/my_docker/opensearch_docker/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~/_practice/my_docker/opensearch_docker/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~/_practice/my_docker/opensearch_docker/.venv/lib/python3.10/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#
# File /usr/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1374 try:
# -> 1375     response.begin()
#    1376 except ConnectionError:
#
# File /usr/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File /usr/lib/python3.10/http/client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/_practice/my_docker/opensearch_docker/.venv/lib/python3.10/site-packages/opensearchpy/connection/http_urllib3.py:280, in Urllib3HttpConnection.perform_request(self, method, url, params, body, timeout, ignore, headers)
#     278 self.metrics.request_start()
# --> 280 response = self.pool.urlopen(
#     281     method, url, body, retries=Retry(False), headers=request_headers, **kw
#     282 )
#     283 duration = time.time() - start
#
# File ~/_practice/my_docker/opensearch_docker/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File ~/_practice/my_docker/opensearch_docker/.venv/lib/python3.10/site-packages/urllib3/util/retry.py:449, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     447 if self.total is False and error:
#     448     # Disabled, indicate to re-raise the error.
# --> 449     raise reraise(type(error), error, _stacktrace)
#     451 total = self.total
#
# File ~/_practice/my_docker/opensearch_docker/.venv/lib/python3.10/site-packages/urllib3/util/util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File ~/_practice/my_docker/opensearch_docker/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~/_practice/my_docker/opensearch_docker/.venv/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~/_practice/my_docker/opensearch_docker/.venv/lib/python3.10/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#
# File /usr/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1374 try:
# -> 1375     response.begin()
#    1376 except ConnectionError:
#
# File /usr/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File /usr/lib/python3.10/http/client.py:287, in HTTPResponse._read_status(self)
#     284 if not line:
#     285     # Presumably, the server closed the connection before
#     286     # sending a valid response.
# --> 287     raise RemoteDisconnected("Remote end closed connection without"
#     288                              " response")
#     289 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[171], line 2
#       1 # you can specify custom field names to match the fields you're using to store your embedding, document text value, and metadata
# ----> 2 docs = docsearch.similarity_search(
#       3     "Who was asking about getting lunch today?",
#       4     search_type="script_scoring",
#       5     space_type="cosinesimil",
#       6     vector_field="message_embedding",
#       7     text_field="message",
#       8     metadata_field="message_metadata",
#       9 )
#
# File ~/_practice/my_docker/opensearch_docker/.venv/lib/python3.10/site-packages/langchain_community/vectorstores/opensearch_vector_search.py:801, in OpenSearchVectorSearch.similarity_search(self, query, k, score_threshold, **kwargs)
#     736 def similarity_search(
#     737     self,
#     738     query: str,
#    (...)
#     741     **kwargs: Any,
#     742 ) -> List[Document]:
#     743     """Return docs most similar to query.
#     744
#     745     By default, supports Approximate Search.
#    (...)
#     799         nearest neighbors; default: {"match_all": {}}
#     800     """
# --> 801     docs_with_scores = self.similarity_search_with_score(
#     802         query, k, score_threshold, **kwargs
#     803     )
#     804     return [doc[0] for doc in docs_with_scores]
#
# File ~/_practice/my_docker/opensearch_docker/.venv/lib/python3.10/site-packages/langchain_community/vectorstores/opensearch_vector_search.py:844, in OpenSearchVectorSearch.similarity_search_with_score(self, query, k, score_threshold, **kwargs)
#     826 """Return docs and it's scores most similar to query.
#     827
#     828 By default, supports Approximate Search.
#    (...)
#     841     same as `similarity_search`
#     842 """
#     843 embedding = self.embedding_function.embed_query(query)
# --> 844 return self.similarity_search_with_score_by_vector(
#     845     embedding, k, score_threshold, **kwargs
#     846 )
#
# File ~/_practice/my_docker/opensearch_docker/.venv/lib/python3.10/site-packages/langchain_community/vectorstores/opensearch_vector_search.py:875, in OpenSearchVectorSearch.similarity_search_with_score_by_vector(self, embedding, k, score_threshold, **kwargs)
#     872 text_field = kwargs.get("text_field", "text")
#     873 metadata_field = kwargs.get("metadata_field", "metadata")
# --> 875 hits = self._raw_similarity_search_with_score_by_vector(
#     876     embedding=embedding, k=k, score_threshold=score_threshold, **kwargs
#     877 )
#     879 documents_with_scores = [
#     880     (
#     881         Document(
#    (...)
#     891     for hit in hits
#     892 ]
#     893 return documents_with_scores
#
# File ~/_practice/my_docker/opensearch_docker/.venv/lib/python3.10/site-packages/langchain_community/vectorstores/opensearch_vector_search.py:1032, in OpenSearchVectorSearch._raw_similarity_search_with_score_by_vector(self, embedding, k, score_threshold, **kwargs)
#    1029 else:
#    1030     raise ValueError("Invalid `search_type` provided as an argument")
# -> 1032 response = self.client.search(index=index_name, body=search_query)
#    1034 return [hit for hit in response["hits"]["hits"]]
#
# File ~/_practice/my_docker/opensearch_docker/.venv/lib/python3.10/site-packages/opensearchpy/client/utils.py:176, in query_params.<locals>._wrapper.<locals>._wrapped(*args, **kwargs)
#     173         if v is not None:
#     174             params[p] = _escape(v)
# --> 176 return func(*args, params=params, headers=headers, **kwargs)
#
# File ~/_practice/my_docker/opensearch_docker/.venv/lib/python3.10/site-packages/opensearchpy/client/__init__.py:2364, in OpenSearch.search(self, body, index, params, headers)
#    2361 if "from_" in params:
#    2362     params["from"] = params.pop("from_")
# -> 2364 return self.transport.perform_request(
#    2365     "POST",
#    2366     _make_path(index, "_search"),
#    2367     params=params,
#    2368     headers=headers,
#    2369     body=body,
#    2370 )
#
# File ~/_practice/my_docker/opensearch_docker/.venv/lib/python3.10/site-packages/opensearchpy/transport.py:453, in Transport.perform_request(self, method, url, params, body, timeout, ignore, headers)
#     451     # raise exception on last retry
#     452     if attempt == self.max_retries:
# --> 453         raise e
#     454 else:
#     455     raise e
#
# File ~/_practice/my_docker/opensearch_docker/.venv/lib/python3.10/site-packages/opensearchpy/transport.py:416, in Transport.perform_request(self, method, url, params, body, timeout, ignore, headers)
#     413 connection = self.get_connection()
#     415 try:
# --> 416     status, headers_response, data = connection.perform_request(
#     417         method,
#     418         url,
#     419         params,
#     420         body,
#     421         headers=headers,
#     422         ignore=ignore,
#     423         timeout=timeout,
#     424     )
#     426     # Lowercase all the header names for consistency in accessing them.
#     427     headers_response = {
#     428         header.lower(): value for header, value in headers_response.items()
#     429     }
#
# File ~/_practice/my_docker/opensearch_docker/.venv/lib/python3.10/site-packages/opensearchpy/connection/http_urllib3.py:295, in Urllib3HttpConnection.perform_request(self, method, url, params, body, timeout, ignore, headers)
#     293     if isinstance(e, ReadTimeoutError):
#     294         raise ConnectionTimeout("TIMEOUT", str(e), e)
# --> 295     raise ConnectionError("N/A", str(e), e)
#     296 finally:
#     297     self.metrics.request_end()
#
# ConnectionError: ConnectionError(('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))) caused by: ProtocolError(('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')))

# %% [markdown]
# # Upload Data into Opensearch

# %%
from opensearchpy import OpenSearch

# %% [markdown]
# ## Step 1: Connect to OpenSearch

# %%
username = os.environ.get("OPENSEARCH_USERNAME")
password = os.environ.get("OPENSEARCH_PASSWORD")

client = OpenSearch(
    hosts=[{"host": "localhost", "port": 9200}],
    http_auth=(username, password),  # Basic Auth
    use_ssl=True,  # Enable SSL if needed
    verify_certs=False  # Disable SSL verification if using self-signed certs
)
# Out:
# /home/softsuave/_practice/my_docker/opensearch_docker/.venv/lib/python3.10/site-packages/opensearchpy/connection/http_urllib3.py:214: UserWarning: Connecting to https://localhost:9200 using SSL with verify_certs=False is insecure.
#   warnings.warn(

# %%
file_path = "temp/frappe_framework_v1.csv" # This dataset won't be available in the git repository use your own

# %% [markdown]
# ## Step 2: Create or check if an index exists

# %%
index_name = "frappe_framework_v1"
if not client.indices.exists(index=index_name):
    client.indices.create(index=index_name)

# %% [markdown]
# ## Step 3: Prepare data (example with a pandas DataFrame)

# %%
import pandas as pd
df = pd.read_csv(file_path)

# %%
# Convert DataFrame to a list of dictionaries (JSON-like)
documents = df.to_dict(orient="records")

# %% [markdown]
# ## Step 4: Upload data (indexing each document)

# %%
for i, doc in enumerate(documents):
    response = client.index(index=index_name, id=i, body=doc)
    print(f"Document {i} indexing response: {response}")
# Out:
# Document 0 indexing response: {'_index': 'frappe_framework_v1', '_id': '0', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 0, '_primary_term': 1}
# Document 1 indexing response: {'_index': 'frappe_framework_v1', '_id': '1', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1, '_primary_term': 1}
# Document 2 indexing response: {'_index': 'frappe_framework_v1', '_id': '2', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 2, '_primary_term': 1}
# Document 3 indexing response: {'_index': 'frappe_framework_v1', '_id': '3', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 3, '_primary_term': 1}
# Document 4 indexing response: {'_index': 'frappe_framework_v1', '_id': '4', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 4, '_primary_term': 1}
# Document 5 indexing response: {'_index': 'frappe_framework_v1', '_id': '5', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 5, '_primary_term': 1}
# Document 6 indexing response: {'_index': 'frappe_framework_v1', '_id': '6', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 6, '_primary_term': 1}
# Document 7 indexing response: {'_index': 'frappe_framework_v1', '_id': '7', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 7, '_primary_term': 1}
# Document 8 indexing response: {'_index': 'frappe_framework_v1', '_id': '8', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 8, '_primary_term': 1}
# Document 9 indexing response: {'_index': 'frappe_framework_v1', '_id': '9', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 9, '_primary_term': 1}
# Document 10 indexing response: {'_index': 'frappe_framework_v1', '_id': '10', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 10, '_primary_term': 1}
# Document 11 indexing response: {'_index': 'frappe_framework_v1', '_id': '11', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 11, '_primary_term': 1}
# Document 12 indexing response: {'_index': 'frappe_framework_v1', '_id': '12', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 12, '_primary_term': 1}
# Document 13 indexing response: {'_index': 'frappe_framework_v1', '_id': '13', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 13, '_primary_term': 1}
# Document 14 indexing response: {'_index': 'frappe_framework_v1', '_id': '14', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 14, '_primary_term': 1}
# Document 15 indexing response: {'_index': 'frappe_framework_v1', '_id': '15', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 15, '_primary_term': 1}
# Document 16 indexing response: {'_index': 'frappe_framework_v1', '_id': '16', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 16, '_primary_term': 1}
# Document 17 indexing response: {'_index': 'frappe_framework_v1', '_id': '17', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 17, '_primary_term': 1}
# Document 18 indexing response: {'_index': 'frappe_framework_v1', '_id': '18', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 18, '_primary_term': 1}
# Document 19 indexing response: {'_index': 'frappe_framework_v1', '_id': '19', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 19, '_primary_term': 1}
# Document 20 indexing response: {'_index': 'frappe_framework_v1', '_id': '20', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 20, '_primary_term': 1}
# Document 21 indexing response: {'_index': 'frappe_framework_v1', '_id': '21', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 21, '_primary_term': 1}
# Document 22 indexing response: {'_index': 'frappe_framework_v1', '_id': '22', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 22, '_primary_term': 1}
# Document 23 indexing response: {'_index': 'frappe_framework_v1', '_id': '23', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 23, '_primary_term': 1}
# Document 24 indexing response: {'_index': 'frappe_framework_v1', '_id': '24', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 24, '_primary_term': 1}
# Document 25 indexing response: {'_index': 'frappe_framework_v1', '_id': '25', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 25, '_primary_term': 1}
# Document 26 indexing response: {'_index': 'frappe_framework_v1', '_id': '26', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 26, '_primary_term': 1}
# Document 27 indexing response: {'_index': 'frappe_framework_v1', '_id': '27', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 27, '_primary_term': 1}
# Document 28 indexing response: {'_index': 'frappe_framework_v1', '_id': '28', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 28, '_primary_term': 1}
# Document 29 indexing response: {'_index': 'frappe_framework_v1', '_id': '29', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 29, '_primary_term': 1}
# Document 30 indexing response: {'_index': 'frappe_framework_v1', '_id': '30', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 30, '_primary_term': 1}
# Document 31 indexing response: {'_index': 'frappe_framework_v1', '_id': '31', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 31, '_primary_term': 1}
# Document 32 indexing response: {'_index': 'frappe_framework_v1', '_id': '32', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 32, '_primary_term': 1}
# Document 33 indexing response: {'_index': 'frappe_framework_v1', '_id': '33', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 33, '_primary_term': 1}
# Document 34 indexing response: {'_index': 'frappe_framework_v1', '_id': '34', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 34, '_primary_term': 1}
# Document 35 indexing response: {'_index': 'frappe_framework_v1', '_id': '35', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 35, '_primary_term': 1}
# Document 36 indexing response: {'_index': 'frappe_framework_v1', '_id': '36', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 36, '_primary_term': 1}
# Document 37 indexing response: {'_index': 'frappe_framework_v1', '_id': '37', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 37, '_primary_term': 1}
# Document 38 indexing response: {'_index': 'frappe_framework_v1', '_id': '38', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 38, '_primary_term': 1}
# Document 39 indexing response: {'_index': 'frappe_framework_v1', '_id': '39', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 39, '_primary_term': 1}
# Document 40 indexing response: {'_index': 'frappe_framework_v1', '_id': '40', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 40, '_primary_term': 1}
# Document 41 indexing response: {'_index': 'frappe_framework_v1', '_id': '41', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 41, '_primary_term': 1}
# Document 42 indexing response: {'_index': 'frappe_framework_v1', '_id': '42', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 42, '_primary_term': 1}
# Document 43 indexing response: {'_index': 'frappe_framework_v1', '_id': '43', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 43, '_primary_term': 1}
# Document 44 indexing response: {'_index': 'frappe_framework_v1', '_id': '44', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 44, '_primary_term': 1}
# Document 45 indexing response: {'_index': 'frappe_framework_v1', '_id': '45', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 45, '_primary_term': 1}
# Document 46 indexing response: {'_index': 'frappe_framework_v1', '_id': '46', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 46, '_primary_term': 1}
# Document 47 indexing response: {'_index': 'frappe_framework_v1', '_id': '47', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 47, '_primary_term': 1}
# Document 48 indexing response: {'_index': 'frappe_framework_v1', '_id': '48', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 48, '_primary_term': 1}
# Document 49 indexing response: {'_index': 'frappe_framework_v1', '_id': '49', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 49, '_primary_term': 1}
# Document 50 indexing response: {'_index': 'frappe_framework_v1', '_id': '50', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 50, '_primary_term': 1}
# Document 51 indexing response: {'_index': 'frappe_framework_v1', '_id': '51', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 51, '_primary_term': 1}
# Document 52 indexing response: {'_index': 'frappe_framework_v1', '_id': '52', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 52, '_primary_term': 1}
# Document 53 indexing response: {'_index': 'frappe_framework_v1', '_id': '53', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 53, '_primary_term': 1}
# Document 54 indexing response: {'_index': 'frappe_framework_v1', '_id': '54', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 54, '_primary_term': 1}
# Document 55 indexing response: {'_index': 'frappe_framework_v1', '_id': '55', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 55, '_primary_term': 1}
# Document 56 indexing response: {'_index': 'frappe_framework_v1', '_id': '56', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 56, '_primary_term': 1}
# Document 57 indexing response: {'_index': 'frappe_framework_v1', '_id': '57', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 57, '_primary_term': 1}
# Document 58 indexing response: {'_index': 'frappe_framework_v1', '_id': '58', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 58, '_primary_term': 1}
# Document 59 indexing response: {'_index': 'frappe_framework_v1', '_id': '59', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 59, '_primary_term': 1}
# Document 60 indexing response: {'_index': 'frappe_framework_v1', '_id': '60', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 60, '_primary_term': 1}
# Document 61 indexing response: {'_index': 'frappe_framework_v1', '_id': '61', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 61, '_primary_term': 1}
# Document 62 indexing response: {'_index': 'frappe_framework_v1', '_id': '62', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 62, '_primary_term': 1}
# Document 63 indexing response: {'_index': 'frappe_framework_v1', '_id': '63', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 63, '_primary_term': 1}
# Document 64 indexing response: {'_index': 'frappe_framework_v1', '_id': '64', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 64, '_primary_term': 1}
# Document 65 indexing response: {'_index': 'frappe_framework_v1', '_id': '65', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 65, '_primary_term': 1}
# Document 66 indexing response: {'_index': 'frappe_framework_v1', '_id': '66', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 66, '_primary_term': 1}
# Document 67 indexing response: {'_index': 'frappe_framework_v1', '_id': '67', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 67, '_primary_term': 1}
# Document 68 indexing response: {'_index': 'frappe_framework_v1', '_id': '68', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 68, '_primary_term': 1}
# Document 69 indexing response: {'_index': 'frappe_framework_v1', '_id': '69', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 69, '_primary_term': 1}
# Document 70 indexing response: {'_index': 'frappe_framework_v1', '_id': '70', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 70, '_primary_term': 1}
# Document 71 indexing response: {'_index': 'frappe_framework_v1', '_id': '71', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 71, '_primary_term': 1}
# Document 72 indexing response: {'_index': 'frappe_framework_v1', '_id': '72', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 72, '_primary_term': 1}
# Document 73 indexing response: {'_index': 'frappe_framework_v1', '_id': '73', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 73, '_primary_term': 1}
# Document 74 indexing response: {'_index': 'frappe_framework_v1', '_id': '74', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 74, '_primary_term': 1}
# Document 75 indexing response: {'_index': 'frappe_framework_v1', '_id': '75', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 75, '_primary_term': 1}
# Document 76 indexing response: {'_index': 'frappe_framework_v1', '_id': '76', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 76, '_primary_term': 1}
# Document 77 indexing response: {'_index': 'frappe_framework_v1', '_id': '77', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 77, '_primary_term': 1}
# Document 78 indexing response: {'_index': 'frappe_framework_v1', '_id': '78', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 78, '_primary_term': 1}
# Document 79 indexing response: {'_index': 'frappe_framework_v1', '_id': '79', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 79, '_primary_term': 1}
# Document 80 indexing response: {'_index': 'frappe_framework_v1', '_id': '80', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 80, '_primary_term': 1}
# Document 81 indexing response: {'_index': 'frappe_framework_v1', '_id': '81', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 81, '_primary_term': 1}
# Document 82 indexing response: {'_index': 'frappe_framework_v1', '_id': '82', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 82, '_primary_term': 1}
# Document 83 indexing response: {'_index': 'frappe_framework_v1', '_id': '83', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 83, '_primary_term': 1}
# Document 84 indexing response: {'_index': 'frappe_framework_v1', '_id': '84', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 84, '_primary_term': 1}
# Document 85 indexing response: {'_index': 'frappe_framework_v1', '_id': '85', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 85, '_primary_term': 1}
# Document 86 indexing response: {'_index': 'frappe_framework_v1', '_id': '86', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 86, '_primary_term': 1}
# Document 87 indexing response: {'_index': 'frappe_framework_v1', '_id': '87', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 87, '_primary_term': 1}
# Document 88 indexing response: {'_index': 'frappe_framework_v1', '_id': '88', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 88, '_primary_term': 1}
# Document 89 indexing response: {'_index': 'frappe_framework_v1', '_id': '89', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 89, '_primary_term': 1}
# Document 90 indexing response: {'_index': 'frappe_framework_v1', '_id': '90', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 90, '_primary_term': 1}
# Document 91 indexing response: {'_index': 'frappe_framework_v1', '_id': '91', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 91, '_primary_term': 1}
# Document 92 indexing response: {'_index': 'frappe_framework_v1', '_id': '92', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 92, '_primary_term': 1}
# Document 93 indexing response: {'_index': 'frappe_framework_v1', '_id': '93', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 93, '_primary_term': 1}
# Document 94 indexing response: {'_index': 'frappe_framework_v1', '_id': '94', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 94, '_primary_term': 1}
# Document 95 indexing response: {'_index': 'frappe_framework_v1', '_id': '95', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 95, '_primary_term': 1}
# Document 96 indexing response: {'_index': 'frappe_framework_v1', '_id': '96', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 96, '_primary_term': 1}
# Document 97 indexing response: {'_index': 'frappe_framework_v1', '_id': '97', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 97, '_primary_term': 1}
# Document 98 indexing response: {'_index': 'frappe_framework_v1', '_id': '98', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 98, '_primary_term': 1}
# Document 99 indexing response: {'_index': 'frappe_framework_v1', '_id': '99', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 99, '_primary_term': 1}
# Document 100 indexing response: {'_index': 'frappe_framework_v1', '_id': '100', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 100, '_primary_term': 1}
# Document 101 indexing response: {'_index': 'frappe_framework_v1', '_id': '101', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 101, '_primary_term': 1}
# Document 102 indexing response: {'_index': 'frappe_framework_v1', '_id': '102', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 102, '_primary_term': 1}
# Document 103 indexing response: {'_index': 'frappe_framework_v1', '_id': '103', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 103, '_primary_term': 1}
# Document 104 indexing response: {'_index': 'frappe_framework_v1', '_id': '104', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 104, '_primary_term': 1}
# Document 105 indexing response: {'_index': 'frappe_framework_v1', '_id': '105', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 105, '_primary_term': 1}
# Document 106 indexing response: {'_index': 'frappe_framework_v1', '_id': '106', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 106, '_primary_term': 1}
# Document 107 indexing response: {'_index': 'frappe_framework_v1', '_id': '107', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 107, '_primary_term': 1}
# Document 108 indexing response: {'_index': 'frappe_framework_v1', '_id': '108', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 108, '_primary_term': 1}
# Document 109 indexing response: {'_index': 'frappe_framework_v1', '_id': '109', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 109, '_primary_term': 1}
# Document 110 indexing response: {'_index': 'frappe_framework_v1', '_id': '110', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 110, '_primary_term': 1}
# Document 111 indexing response: {'_index': 'frappe_framework_v1', '_id': '111', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 111, '_primary_term': 1}
# Document 112 indexing response: {'_index': 'frappe_framework_v1', '_id': '112', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 112, '_primary_term': 1}
# Document 113 indexing response: {'_index': 'frappe_framework_v1', '_id': '113', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 113, '_primary_term': 1}
# Document 114 indexing response: {'_index': 'frappe_framework_v1', '_id': '114', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 114, '_primary_term': 1}
# Document 115 indexing response: {'_index': 'frappe_framework_v1', '_id': '115', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 115, '_primary_term': 1}
# Document 116 indexing response: {'_index': 'frappe_framework_v1', '_id': '116', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 116, '_primary_term': 1}
# Document 117 indexing response: {'_index': 'frappe_framework_v1', '_id': '117', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 117, '_primary_term': 1}
# Document 118 indexing response: {'_index': 'frappe_framework_v1', '_id': '118', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 118, '_primary_term': 1}
# Document 119 indexing response: {'_index': 'frappe_framework_v1', '_id': '119', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 119, '_primary_term': 1}
# Document 120 indexing response: {'_index': 'frappe_framework_v1', '_id': '120', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 120, '_primary_term': 1}
# Document 121 indexing response: {'_index': 'frappe_framework_v1', '_id': '121', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 121, '_primary_term': 1}
# Document 122 indexing response: {'_index': 'frappe_framework_v1', '_id': '122', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 122, '_primary_term': 1}
# Document 123 indexing response: {'_index': 'frappe_framework_v1', '_id': '123', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 123, '_primary_term': 1}
# Document 124 indexing response: {'_index': 'frappe_framework_v1', '_id': '124', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 124, '_primary_term': 1}
# Document 125 indexing response: {'_index': 'frappe_framework_v1', '_id': '125', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 125, '_primary_term': 1}
# Document 126 indexing response: {'_index': 'frappe_framework_v1', '_id': '126', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 126, '_primary_term': 1}
# Document 127 indexing response: {'_index': 'frappe_framework_v1', '_id': '127', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 127, '_primary_term': 1}
# Document 128 indexing response: {'_index': 'frappe_framework_v1', '_id': '128', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 128, '_primary_term': 1}
# Document 129 indexing response: {'_index': 'frappe_framework_v1', '_id': '129', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 129, '_primary_term': 1}
# Document 130 indexing response: {'_index': 'frappe_framework_v1', '_id': '130', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 130, '_primary_term': 1}
# Document 131 indexing response: {'_index': 'frappe_framework_v1', '_id': '131', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 131, '_primary_term': 1}
# Document 132 indexing response: {'_index': 'frappe_framework_v1', '_id': '132', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 132, '_primary_term': 1}
# Document 133 indexing response: {'_index': 'frappe_framework_v1', '_id': '133', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 133, '_primary_term': 1}
# Document 134 indexing response: {'_index': 'frappe_framework_v1', '_id': '134', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 134, '_primary_term': 1}
# Document 135 indexing response: {'_index': 'frappe_framework_v1', '_id': '135', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 135, '_primary_term': 1}
# Document 136 indexing response: {'_index': 'frappe_framework_v1', '_id': '136', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 136, '_primary_term': 1}
# Document 137 indexing response: {'_index': 'frappe_framework_v1', '_id': '137', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 137, '_primary_term': 1}
# Document 138 indexing response: {'_index': 'frappe_framework_v1', '_id': '138', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 138, '_primary_term': 1}
# Document 139 indexing response: {'_index': 'frappe_framework_v1', '_id': '139', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 139, '_primary_term': 1}
# Document 140 indexing response: {'_index': 'frappe_framework_v1', '_id': '140', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 140, '_primary_term': 1}
# Document 141 indexing response: {'_index': 'frappe_framework_v1', '_id': '141', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 141, '_primary_term': 1}
# Document 142 indexing response: {'_index': 'frappe_framework_v1', '_id': '142', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 142, '_primary_term': 1}
# Document 143 indexing response: {'_index': 'frappe_framework_v1', '_id': '143', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 143, '_primary_term': 1}
# Document 144 indexing response: {'_index': 'frappe_framework_v1', '_id': '144', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 144, '_primary_term': 1}
# Document 145 indexing response: {'_index': 'frappe_framework_v1', '_id': '145', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 145, '_primary_term': 1}
# Document 146 indexing response: {'_index': 'frappe_framework_v1', '_id': '146', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 146, '_primary_term': 1}
# Document 147 indexing response: {'_index': 'frappe_framework_v1', '_id': '147', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 147, '_primary_term': 1}
# Document 148 indexing response: {'_index': 'frappe_framework_v1', '_id': '148', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 148, '_primary_term': 1}
# Document 149 indexing response: {'_index': 'frappe_framework_v1', '_id': '149', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 149, '_primary_term': 1}
# Document 150 indexing response: {'_index': 'frappe_framework_v1', '_id': '150', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 150, '_primary_term': 1}
# Document 151 indexing response: {'_index': 'frappe_framework_v1', '_id': '151', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 151, '_primary_term': 1}
# Document 152 indexing response: {'_index': 'frappe_framework_v1', '_id': '152', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 152, '_primary_term': 1}
# Document 153 indexing response: {'_index': 'frappe_framework_v1', '_id': '153', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 153, '_primary_term': 1}
# Document 154 indexing response: {'_index': 'frappe_framework_v1', '_id': '154', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 154, '_primary_term': 1}
# Document 155 indexing response: {'_index': 'frappe_framework_v1', '_id': '155', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 155, '_primary_term': 1}
# Document 156 indexing response: {'_index': 'frappe_framework_v1', '_id': '156', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 156, '_primary_term': 1}
# Document 157 indexing response: {'_index': 'frappe_framework_v1', '_id': '157', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 157, '_primary_term': 1}
# Document 158 indexing response: {'_index': 'frappe_framework_v1', '_id': '158', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 158, '_primary_term': 1}
# Document 159 indexing response: {'_index': 'frappe_framework_v1', '_id': '159', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 159, '_primary_term': 1}
# Document 160 indexing response: {'_index': 'frappe_framework_v1', '_id': '160', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 160, '_primary_term': 1}
# Document 161 indexing response: {'_index': 'frappe_framework_v1', '_id': '161', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 161, '_primary_term': 1}
# Document 162 indexing response: {'_index': 'frappe_framework_v1', '_id': '162', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 162, '_primary_term': 1}
# Document 163 indexing response: {'_index': 'frappe_framework_v1', '_id': '163', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 163, '_primary_term': 1}
# Document 164 indexing response: {'_index': 'frappe_framework_v1', '_id': '164', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 164, '_primary_term': 1}
# Document 165 indexing response: {'_index': 'frappe_framework_v1', '_id': '165', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 165, '_primary_term': 1}
# Document 166 indexing response: {'_index': 'frappe_framework_v1', '_id': '166', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 166, '_primary_term': 1}
# Document 167 indexing response: {'_index': 'frappe_framework_v1', '_id': '167', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 167, '_primary_term': 1}
# Document 168 indexing response: {'_index': 'frappe_framework_v1', '_id': '168', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 168, '_primary_term': 1}
# Document 169 indexing response: {'_index': 'frappe_framework_v1', '_id': '169', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 169, '_primary_term': 1}
# Document 170 indexing response: {'_index': 'frappe_framework_v1', '_id': '170', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 170, '_primary_term': 1}
# Document 171 indexing response: {'_index': 'frappe_framework_v1', '_id': '171', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 171, '_primary_term': 1}
# Document 172 indexing response: {'_index': 'frappe_framework_v1', '_id': '172', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 172, '_primary_term': 1}
# Document 173 indexing response: {'_index': 'frappe_framework_v1', '_id': '173', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 173, '_primary_term': 1}
# Document 174 indexing response: {'_index': 'frappe_framework_v1', '_id': '174', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 174, '_primary_term': 1}
# Document 175 indexing response: {'_index': 'frappe_framework_v1', '_id': '175', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 175, '_primary_term': 1}
# Document 176 indexing response: {'_index': 'frappe_framework_v1', '_id': '176', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 176, '_primary_term': 1}
# Document 177 indexing response: {'_index': 'frappe_framework_v1', '_id': '177', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 177, '_primary_term': 1}
# Document 178 indexing response: {'_index': 'frappe_framework_v1', '_id': '178', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 178, '_primary_term': 1}
# Document 179 indexing response: {'_index': 'frappe_framework_v1', '_id': '179', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 179, '_primary_term': 1}
# Document 180 indexing response: {'_index': 'frappe_framework_v1', '_id': '180', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 180, '_primary_term': 1}
# Document 181 indexing response: {'_index': 'frappe_framework_v1', '_id': '181', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 181, '_primary_term': 1}
# Document 182 indexing response: {'_index': 'frappe_framework_v1', '_id': '182', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 182, '_primary_term': 1}
# Document 183 indexing response: {'_index': 'frappe_framework_v1', '_id': '183', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 183, '_primary_term': 1}
# Document 184 indexing response: {'_index': 'frappe_framework_v1', '_id': '184', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 184, '_primary_term': 1}
# Document 185 indexing response: {'_index': 'frappe_framework_v1', '_id': '185', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 185, '_primary_term': 1}
# Document 186 indexing response: {'_index': 'frappe_framework_v1', '_id': '186', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 186, '_primary_term': 1}
# Document 187 indexing response: {'_index': 'frappe_framework_v1', '_id': '187', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 187, '_primary_term': 1}
# Document 188 indexing response: {'_index': 'frappe_framework_v1', '_id': '188', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 188, '_primary_term': 1}
# Document 189 indexing response: {'_index': 'frappe_framework_v1', '_id': '189', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 189, '_primary_term': 1}
# Document 190 indexing response: {'_index': 'frappe_framework_v1', '_id': '190', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 190, '_primary_term': 1}
# Document 191 indexing response: {'_index': 'frappe_framework_v1', '_id': '191', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 191, '_primary_term': 1}
# Document 192 indexing response: {'_index': 'frappe_framework_v1', '_id': '192', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 192, '_primary_term': 1}
# Document 193 indexing response: {'_index': 'frappe_framework_v1', '_id': '193', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 193, '_primary_term': 1}
# Document 194 indexing response: {'_index': 'frappe_framework_v1', '_id': '194', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 194, '_primary_term': 1}
# Document 195 indexing response: {'_index': 'frappe_framework_v1', '_id': '195', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 195, '_primary_term': 1}
# Document 196 indexing response: {'_index': 'frappe_framework_v1', '_id': '196', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 196, '_primary_term': 1}
# Document 197 indexing response: {'_index': 'frappe_framework_v1', '_id': '197', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 197, '_primary_term': 1}
# Document 198 indexing response: {'_index': 'frappe_framework_v1', '_id': '198', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 198, '_primary_term': 1}
# Document 199 indexing response: {'_index': 'frappe_framework_v1', '_id': '199', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 199, '_primary_term': 1}
# Document 200 indexing response: {'_index': 'frappe_framework_v1', '_id': '200', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 200, '_primary_term': 1}
# Document 201 indexing response: {'_index': 'frappe_framework_v1', '_id': '201', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 201, '_primary_term': 1}
# Document 202 indexing response: {'_index': 'frappe_framework_v1', '_id': '202', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 202, '_primary_term': 1}
# Document 203 indexing response: {'_index': 'frappe_framework_v1', '_id': '203', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 203, '_primary_term': 1}
# Document 204 indexing response: {'_index': 'frappe_framework_v1', '_id': '204', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 204, '_primary_term': 1}
# Document 205 indexing response: {'_index': 'frappe_framework_v1', '_id': '205', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 205, '_primary_term': 1}
# Document 206 indexing response: {'_index': 'frappe_framework_v1', '_id': '206', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 206, '_primary_term': 1}
# Document 207 indexing response: {'_index': 'frappe_framework_v1', '_id': '207', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 207, '_primary_term': 1}
# Document 208 indexing response: {'_index': 'frappe_framework_v1', '_id': '208', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 208, '_primary_term': 1}
# Document 209 indexing response: {'_index': 'frappe_framework_v1', '_id': '209', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 209, '_primary_term': 1}
# Document 210 indexing response: {'_index': 'frappe_framework_v1', '_id': '210', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 210, '_primary_term': 1}
# Document 211 indexing response: {'_index': 'frappe_framework_v1', '_id': '211', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 211, '_primary_term': 1}
# Document 212 indexing response: {'_index': 'frappe_framework_v1', '_id': '212', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 212, '_primary_term': 1}
# Document 213 indexing response: {'_index': 'frappe_framework_v1', '_id': '213', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 213, '_primary_term': 1}
# Document 214 indexing response: {'_index': 'frappe_framework_v1', '_id': '214', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 214, '_primary_term': 1}
# Document 215 indexing response: {'_index': 'frappe_framework_v1', '_id': '215', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 215, '_primary_term': 1}
# Document 216 indexing response: {'_index': 'frappe_framework_v1', '_id': '216', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 216, '_primary_term': 1}
# Document 217 indexing response: {'_index': 'frappe_framework_v1', '_id': '217', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 217, '_primary_term': 1}
# Document 218 indexing response: {'_index': 'frappe_framework_v1', '_id': '218', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 218, '_primary_term': 1}
# Document 219 indexing response: {'_index': 'frappe_framework_v1', '_id': '219', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 219, '_primary_term': 1}
# Document 220 indexing response: {'_index': 'frappe_framework_v1', '_id': '220', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 220, '_primary_term': 1}
# Document 221 indexing response: {'_index': 'frappe_framework_v1', '_id': '221', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 221, '_primary_term': 1}
# Document 222 indexing response: {'_index': 'frappe_framework_v1', '_id': '222', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 222, '_primary_term': 1}
# Document 223 indexing response: {'_index': 'frappe_framework_v1', '_id': '223', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 223, '_primary_term': 1}
# Document 224 indexing response: {'_index': 'frappe_framework_v1', '_id': '224', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 224, '_primary_term': 1}
# Document 225 indexing response: {'_index': 'frappe_framework_v1', '_id': '225', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 225, '_primary_term': 1}
# Document 226 indexing response: {'_index': 'frappe_framework_v1', '_id': '226', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 226, '_primary_term': 1}
# Document 227 indexing response: {'_index': 'frappe_framework_v1', '_id': '227', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 227, '_primary_term': 1}
# Document 228 indexing response: {'_index': 'frappe_framework_v1', '_id': '228', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 228, '_primary_term': 1}
# Document 229 indexing response: {'_index': 'frappe_framework_v1', '_id': '229', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 229, '_primary_term': 1}
# Document 230 indexing response: {'_index': 'frappe_framework_v1', '_id': '230', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 230, '_primary_term': 1}
# Document 231 indexing response: {'_index': 'frappe_framework_v1', '_id': '231', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 231, '_primary_term': 1}
# Document 232 indexing response: {'_index': 'frappe_framework_v1', '_id': '232', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 232, '_primary_term': 1}
# ...
# Document 1283 indexing response: {'_index': 'frappe_framework_v1', '_id': '1283', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1283, '_primary_term': 1}
# Document 1284 indexing response: {'_index': 'frappe_framework_v1', '_id': '1284', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1284, '_primary_term': 1}
# Document 1285 indexing response: {'_index': 'frappe_framework_v1', '_id': '1285', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1285, '_primary_term': 1}
# Document 1286 indexing response: {'_index': 'frappe_framework_v1', '_id': '1286', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1286, '_primary_term': 1}
# Document 1287 indexing response: {'_index': 'frappe_framework_v1', '_id': '1287', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1287, '_primary_term': 1}
# Document 1288 indexing response: {'_index': 'frappe_framework_v1', '_id': '1288', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1288, '_primary_term': 1}
# Document 1289 indexing response: {'_index': 'frappe_framework_v1', '_id': '1289', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1289, '_primary_term': 1}
# Document 1290 indexing response: {'_index': 'frappe_framework_v1', '_id': '1290', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1290, '_primary_term': 1}
# Document 1291 indexing response: {'_index': 'frappe_framework_v1', '_id': '1291', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1291, '_primary_term': 1}
# Document 1292 indexing response: {'_index': 'frappe_framework_v1', '_id': '1292', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1292, '_primary_term': 1}
# Document 1293 indexing response: {'_index': 'frappe_framework_v1', '_id': '1293', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1293, '_primary_term': 1}
# Document 1294 indexing response: {'_index': 'frappe_framework_v1', '_id': '1294', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1294, '_primary_term': 1}
# Document 1295 indexing response: {'_index': 'frappe_framework_v1', '_id': '1295', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1295, '_primary_term': 1}
# Document 1296 indexing response: {'_index': 'frappe_framework_v1', '_id': '1296', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1296, '_primary_term': 1}
# Document 1297 indexing response: {'_index': 'frappe_framework_v1', '_id': '1297', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1297, '_primary_term': 1}
# Document 1298 indexing response: {'_index': 'frappe_framework_v1', '_id': '1298', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1298, '_primary_term': 1}
# Document 1299 indexing response: {'_index': 'frappe_framework_v1', '_id': '1299', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1299, '_primary_term': 1}
# Document 1300 indexing response: {'_index': 'frappe_framework_v1', '_id': '1300', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1300, '_primary_term': 1}
# Document 1301 indexing response: {'_index': 'frappe_framework_v1', '_id': '1301', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1301, '_primary_term': 1}
# Document 1302 indexing response: {'_index': 'frappe_framework_v1', '_id': '1302', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1302, '_primary_term': 1}
# Document 1303 indexing response: {'_index': 'frappe_framework_v1', '_id': '1303', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1303, '_primary_term': 1}
# Document 1304 indexing response: {'_index': 'frappe_framework_v1', '_id': '1304', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1304, '_primary_term': 1}
# Document 1305 indexing response: {'_index': 'frappe_framework_v1', '_id': '1305', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1305, '_primary_term': 1}
# Document 1306 indexing response: {'_index': 'frappe_framework_v1', '_id': '1306', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1306, '_primary_term': 1}
# Document 1307 indexing response: {'_index': 'frappe_framework_v1', '_id': '1307', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1307, '_primary_term': 1}
# Document 1308 indexing response: {'_index': 'frappe_framework_v1', '_id': '1308', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1308, '_primary_term': 1}
# Document 1309 indexing response: {'_index': 'frappe_framework_v1', '_id': '1309', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1309, '_primary_term': 1}
# Document 1310 indexing response: {'_index': 'frappe_framework_v1', '_id': '1310', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1310, '_primary_term': 1}
# Document 1311 indexing response: {'_index': 'frappe_framework_v1', '_id': '1311', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1311, '_primary_term': 1}
# Document 1312 indexing response: {'_index': 'frappe_framework_v1', '_id': '1312', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1312, '_primary_term': 1}
# Document 1313 indexing response: {'_index': 'frappe_framework_v1', '_id': '1313', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1313, '_primary_term': 1}
# Document 1314 indexing response: {'_index': 'frappe_framework_v1', '_id': '1314', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1314, '_primary_term': 1}
# Document 1315 indexing response: {'_index': 'frappe_framework_v1', '_id': '1315', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1315, '_primary_term': 1}
# Document 1316 indexing response: {'_index': 'frappe_framework_v1', '_id': '1316', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1316, '_primary_term': 1}
# Document 1317 indexing response: {'_index': 'frappe_framework_v1', '_id': '1317', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1317, '_primary_term': 1}
# Document 1318 indexing response: {'_index': 'frappe_framework_v1', '_id': '1318', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1318, '_primary_term': 1}
# Document 1319 indexing response: {'_index': 'frappe_framework_v1', '_id': '1319', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1319, '_primary_term': 1}
# Document 1320 indexing response: {'_index': 'frappe_framework_v1', '_id': '1320', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1320, '_primary_term': 1}
# Document 1321 indexing response: {'_index': 'frappe_framework_v1', '_id': '1321', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1321, '_primary_term': 1}
# Document 1322 indexing response: {'_index': 'frappe_framework_v1', '_id': '1322', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1322, '_primary_term': 1}
# Document 1323 indexing response: {'_index': 'frappe_framework_v1', '_id': '1323', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1323, '_primary_term': 1}
# Document 1324 indexing response: {'_index': 'frappe_framework_v1', '_id': '1324', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1324, '_primary_term': 1}
# Document 1325 indexing response: {'_index': 'frappe_framework_v1', '_id': '1325', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1325, '_primary_term': 1}
# Document 1326 indexing response: {'_index': 'frappe_framework_v1', '_id': '1326', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1326, '_primary_term': 1}
# Document 1327 indexing response: {'_index': 'frappe_framework_v1', '_id': '1327', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1327, '_primary_term': 1}
# Document 1328 indexing response: {'_index': 'frappe_framework_v1', '_id': '1328', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1328, '_primary_term': 1}
# Document 1329 indexing response: {'_index': 'frappe_framework_v1', '_id': '1329', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1329, '_primary_term': 1}
# Document 1330 indexing response: {'_index': 'frappe_framework_v1', '_id': '1330', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1330, '_primary_term': 1}
# Document 1331 indexing response: {'_index': 'frappe_framework_v1', '_id': '1331', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1331, '_primary_term': 1}
# Document 1332 indexing response: {'_index': 'frappe_framework_v1', '_id': '1332', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1332, '_primary_term': 1}
# Document 1333 indexing response: {'_index': 'frappe_framework_v1', '_id': '1333', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1333, '_primary_term': 1}
# Document 1334 indexing response: {'_index': 'frappe_framework_v1', '_id': '1334', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1334, '_primary_term': 1}
# Document 1335 indexing response: {'_index': 'frappe_framework_v1', '_id': '1335', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1335, '_primary_term': 1}
# Document 1336 indexing response: {'_index': 'frappe_framework_v1', '_id': '1336', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1336, '_primary_term': 1}
# Document 1337 indexing response: {'_index': 'frappe_framework_v1', '_id': '1337', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1337, '_primary_term': 1}
# Document 1338 indexing response: {'_index': 'frappe_framework_v1', '_id': '1338', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1338, '_primary_term': 1}
# Document 1339 indexing response: {'_index': 'frappe_framework_v1', '_id': '1339', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1339, '_primary_term': 1}
# Document 1340 indexing response: {'_index': 'frappe_framework_v1', '_id': '1340', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1340, '_primary_term': 1}
# Document 1341 indexing response: {'_index': 'frappe_framework_v1', '_id': '1341', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1341, '_primary_term': 1}
# Document 1342 indexing response: {'_index': 'frappe_framework_v1', '_id': '1342', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1342, '_primary_term': 1}
# Document 1343 indexing response: {'_index': 'frappe_framework_v1', '_id': '1343', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1343, '_primary_term': 1}
# Document 1344 indexing response: {'_index': 'frappe_framework_v1', '_id': '1344', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1344, '_primary_term': 1}
# Document 1345 indexing response: {'_index': 'frappe_framework_v1', '_id': '1345', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1345, '_primary_term': 1}
# Document 1346 indexing response: {'_index': 'frappe_framework_v1', '_id': '1346', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1346, '_primary_term': 1}
# Document 1347 indexing response: {'_index': 'frappe_framework_v1', '_id': '1347', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1347, '_primary_term': 1}
# Document 1348 indexing response: {'_index': 'frappe_framework_v1', '_id': '1348', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1348, '_primary_term': 1}
# Document 1349 indexing response: {'_index': 'frappe_framework_v1', '_id': '1349', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1349, '_primary_term': 1}
# Document 1350 indexing response: {'_index': 'frappe_framework_v1', '_id': '1350', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1350, '_primary_term': 1}
# Document 1351 indexing response: {'_index': 'frappe_framework_v1', '_id': '1351', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1351, '_primary_term': 1}
# Document 1352 indexing response: {'_index': 'frappe_framework_v1', '_id': '1352', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1352, '_primary_term': 1}
# Document 1353 indexing response: {'_index': 'frappe_framework_v1', '_id': '1353', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1353, '_primary_term': 1}
# Document 1354 indexing response: {'_index': 'frappe_framework_v1', '_id': '1354', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1354, '_primary_term': 1}
# Document 1355 indexing response: {'_index': 'frappe_framework_v1', '_id': '1355', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1355, '_primary_term': 1}
# Document 1356 indexing response: {'_index': 'frappe_framework_v1', '_id': '1356', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1356, '_primary_term': 1}
# Document 1357 indexing response: {'_index': 'frappe_framework_v1', '_id': '1357', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1357, '_primary_term': 1}
# Document 1358 indexing response: {'_index': 'frappe_framework_v1', '_id': '1358', '_version': 1, 'result': 'created', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 1358, '_primary_term': 1}

# %% [markdown]
# Note : *Optional: Use the Bulk API for Large Data*
#
# For larger datasets, you can use the bulk API to upload data in batches, which is more efficient than uploading one document at a time.

# %% [markdown]
# # Retrive Information

# %%
index_name = 'frappe_framework_v1'

# %% [markdown]
# ## Retrieving All Documents

# %%
query = {
    "query": {
        "match_all": {}  # Retrieves all documents (you can modify this for specific queries)
    }
}

# %%
response = client.search(index=index_name, body=query)
print(f"total documents {response['hits']['total']['value']}")
# Out:
# total documents 1359

# %% [markdown]
# ## Example of a Specific Query

# %%
query = {
    "query": {
        "match": {
            "assistant": "frappe.call"  # Replace with the field and value you're searching for
        }
    }
}

# %%
response = client.search(index=index_name, body=query)

print(f"total matching value {response['hits']['total']['value']}")
# Out:
# total matching value 9

# %% [markdown]
# ## Example with Pagination (Retrieve More Documents):

# %%
# Define the pagination parameters
size = 5  # Number of documents to retrieve per request
from_ = 0  # Starting point for pagination

query = {
    "query": {
        "match_all": {}  # This retrieves all documents
    },
    "size": size,
    "from": from_  # Start from document 0
}

# Perform the search with pagination
response = client.search(index=index_name, body=query)

print(f"total matching value {response['hits']['total']['value']} & size for a page {len(response['hits']['hits'])}")
# Out:
# total matching value 1359 & size for a page 5

# %% [markdown]
# **Move to next page**

# %%
size = 5
from_ = 0
total_documents = 1359  # Based on your sample data

while from_ < total_documents:
    query = {
        "query": {
            "match_all": {}
        },
        "size": size,
        "from": from_
    }

    response = client.search(index=index_name, body=query)

    # Process and print the results
    for hit in response['hits']['hits']:
        pass
        # print(f"ID: {hit['_id']}, User: {hit['_source']['user']}, Assistant: {hit['_source']['assistant']}")

    from_ += size  # Move to the next batch
